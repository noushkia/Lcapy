# %% [markdown]
# # Computer Assignment 3
# # Difference Equation
#
# Kianoush Arshi<br>
# 810198438

# %% [markdown]
# ## Table of Contents
#
# * [Requirements](#Requirements)
# * [The Equation](#The-Equation)
#     * [Z Transform](#Z-Transform)
#     * [Frequency Response](#Frequency-Response)
#     * [Numeric Difference Equation](#Numeric-Difference-Equation)
#     * [Block Diagram](#Block-Diagram)
#     * [System Response](#System-Response)

# %% [markdown]
# # Requirements

# %% [markdown]
# # The Equation
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Z Transform

# %%
.
# Out:
# z⋅(a⋅z + b)
# ────────────
#            2
# c⋅z + d + z

# %% [markdown]
# ## Frequency Response

# %%
Y.IZT()
# Out:
#                      n                                                      n
# ⎛         __________⎞                                  ⎛         __________⎞
# ⎜        ╱  2       ⎟  ⎛           __________      ⎞   ⎜        ╱  2       ⎟
# ⎜  c   ╲╱  c  - 4⋅d ⎟  ⎜          ╱  2             ⎟   ⎜  c   ╲╱  c  - 4⋅d ⎟
# ⎜- ─ - ─────────────⎟ ⋅⎝a⋅c + a⋅╲╱  c  - 4⋅d  - 2⋅b⎠   ⎜- ─ + ─────────────⎟ ⋅
# ⎝  2         2      ⎠                                  ⎝  2         2      ⎠
# ──────────────────────────────────────────────────── + ───────────────────────
#                        __________
#                       ╱  2
#                   2⋅╲╱  c  - 4⋅d                                          2⋅╲╱
#
#
#
# ⎛            __________      ⎞
# ⎜           ╱  2             ⎟
# ⎝-a⋅c + a⋅╲╱  c  - 4⋅d  + 2⋅b⎠
#
# ──────────────────────────────  for n ≥ 0
#  __________
# ╱  2
#   c  - 4⋅d

# %% [markdown]
# ## Numeric Difference Equation

# %%
/
# Out:
# y(n) = x(n) + x(n - 1) - 2⋅y(n - 2) + 3⋅y(n - 1)

# %% [markdown]
# ## Block Diagram

# %%
Y.difference_equation('x', 'y', 'iir').expr
# Out:
# y(n) = a⋅x(n) + b⋅x(n - 1) - c⋅y(n - 1) - d⋅y(n - 2)

# %% [markdown]
# ## System Response

# %%
.
# Out:
#  n
# 2 ⋅u[n]

# %%
lpf_eq.dlti_filter().response(x_n, ni=(1,3))
# Out:
# {_1, 6, 22, 66}
